# %% [markdown]
# # Reading data from .csv files

# %%
import pandas as pd

data1 = pd.read_csv('linkedin_job_postings.csv')
data2 = pd.read_csv('job_skills.csv')
data1
# Out:
#                                                  job_link  \
# 0       https://www.linkedin.com/jobs/view/assistant-n...
# 1       https://www.linkedin.com/jobs/view/executive-c...
# 2       https://www.linkedin.com/jobs/view/sales-lead-...
# 3       https://www.linkedin.com/jobs/view/elevator-pl...
# 4       https://www.linkedin.com/jobs/view/senior-cont...
# ...                                                   ...
# 527496  https://www.linkedin.com/jobs/view/senior-acco...
# 527497  https://www.linkedin.com/jobs/view/registered-...
# 527498  https://www.linkedin.com/jobs/view/juice-baris...
# 527499  https://www.linkedin.com/jobs/view/banquet-and...
# 527500  https://www.linkedin.com/jobs/view/regional-sa...
#
#                   last_processed_time got_summary got_ner is_being_worked  \
# 0       2024-01-19 09:45:09.215838+00           t       t               f
# 1       2024-01-19 09:45:09.215838+00           t       t               f
# ...

# %%
data2
# Out:
#                                                   job_link  \
# 0        https://www.linkedin.com/jobs/view/housekeeper...
# 1        https://www.linkedin.com/jobs/view/assistant-g...
# 2        https://www.linkedin.com/jobs/view/school-base...
# 3        https://www.linkedin.com/jobs/view/electrical-...
# 4        https://www.linkedin.com/jobs/view/electrical-...
# ...                                                    ...
# 1296376  https://www.linkedin.com/jobs/view/community-a...
# 1296377  https://www.linkedin.com/jobs/view/sr-it-analy...
# 1296378  https://www.linkedin.com/jobs/view/operations-...
# 1296379  https://www.linkedin.com/jobs/view/float-patie...
# 1296380  https://www.linkedin.com/jobs/view/conductor-e...
#
#                                                 job_skills
# 0        Building Custodial Services, Cleaning, Janitor...
# 1        Customer service, Restaurant management, Food ...
# 2        Applied Behavior Analysis (ABA), Data analysis...
# ...

# %% [markdown]
# # Cleaning dataset and performing EDA

# %% [markdown]
# ## 1. Merging two .csv files

# %%
job_data = pd.merge(data1, data2, on='job_link', how='left') 
job_data
# Out:
#                                                  job_link  \
# 0       https://www.linkedin.com/jobs/view/assistant-n...
# 1       https://www.linkedin.com/jobs/view/executive-c...
# 2       https://www.linkedin.com/jobs/view/sales-lead-...
# 3       https://www.linkedin.com/jobs/view/elevator-pl...
# 4       https://www.linkedin.com/jobs/view/senior-cont...
# ...                                                   ...
# 527496  https://www.linkedin.com/jobs/view/senior-acco...
# 527497  https://www.linkedin.com/jobs/view/registered-...
# 527498  https://www.linkedin.com/jobs/view/juice-baris...
# 527499  https://www.linkedin.com/jobs/view/banquet-and...
# 527500  https://www.linkedin.com/jobs/view/regional-sa...
#
#                   last_processed_time got_summary got_ner is_being_worked  \
# 0       2024-01-19 09:45:09.215838+00           t       t               f
# 1       2024-01-19 09:45:09.215838+00           t       t               f
# ...

# %% [markdown]
# ## 2. Removing irrelevant columns

# %%
job_data = job_data.drop('got_summary', axis=1)
job_data = job_data.drop('got_ner', axis=1)
job_data = job_data.drop('search_city', axis=1)
job_data = job_data.drop('search_position', axis=1)
job_data = job_data.drop('is_being_worked', axis=1)
job_data
# Out:
#                                                  job_link  \
# 0       https://www.linkedin.com/jobs/view/assistant-n...
# 1       https://www.linkedin.com/jobs/view/executive-c...
# 2       https://www.linkedin.com/jobs/view/sales-lead-...
# 3       https://www.linkedin.com/jobs/view/elevator-pl...
# 4       https://www.linkedin.com/jobs/view/senior-cont...
# ...                                                   ...
# 527496  https://www.linkedin.com/jobs/view/senior-acco...
# 527497  https://www.linkedin.com/jobs/view/registered-...
# 527498  https://www.linkedin.com/jobs/view/juice-baris...
# 527499  https://www.linkedin.com/jobs/view/banquet-and...
# 527500  https://www.linkedin.com/jobs/view/regional-sa...
#
#                   last_processed_time  \
# 0       2024-01-19 09:45:09.215838+00
# 1       2024-01-19 09:45:09.215838+00
# 2       2024-01-21 13:08:11.506112+00
# 3       2024-01-21 06:21:13.609932+00
# 4       2024-01-19 17:11:18.397004+00
# ...

# %% [markdown]
# ## 3. Splitting job_location to City and State

# %%
job_data[['City', 'State']] = [str(loc).split(',')[:2] if len(str(loc).split(',')) > 1 else [loc, None] for loc in job_data['job_location']]
job_data
# Out:
#                                                  job_link  \
# 0       https://www.linkedin.com/jobs/view/assistant-n...
# 1       https://www.linkedin.com/jobs/view/executive-c...
# 2       https://www.linkedin.com/jobs/view/sales-lead-...
# 3       https://www.linkedin.com/jobs/view/elevator-pl...
# 4       https://www.linkedin.com/jobs/view/senior-cont...
# ...                                                   ...
# 527496  https://www.linkedin.com/jobs/view/senior-acco...
# 527497  https://www.linkedin.com/jobs/view/registered-...
# 527498  https://www.linkedin.com/jobs/view/juice-baris...
# 527499  https://www.linkedin.com/jobs/view/banquet-and...
# 527500  https://www.linkedin.com/jobs/view/regional-sa...
#
#                   last_processed_time  \
# 0       2024-01-19 09:45:09.215838+00
# 1       2024-01-19 09:45:09.215838+00
# 2       2024-01-21 13:08:11.506112+00
# 3       2024-01-21 06:21:13.609932+00
# 4       2024-01-19 17:11:18.397004+00
# ...

# %% [markdown]
# ## 4. Drop redundant data column

# %%
job_data = job_data.drop('job_location', axis=1)
job_data
# Out:
#                                                  job_link  \
# 0       https://www.linkedin.com/jobs/view/assistant-n...
# 1       https://www.linkedin.com/jobs/view/executive-c...
# 2       https://www.linkedin.com/jobs/view/sales-lead-...
# 3       https://www.linkedin.com/jobs/view/elevator-pl...
# 4       https://www.linkedin.com/jobs/view/senior-cont...
# ...                                                   ...
# 527496  https://www.linkedin.com/jobs/view/senior-acco...
# 527497  https://www.linkedin.com/jobs/view/registered-...
# 527498  https://www.linkedin.com/jobs/view/juice-baris...
# 527499  https://www.linkedin.com/jobs/view/banquet-and...
# 527500  https://www.linkedin.com/jobs/view/regional-sa...
#
#                   last_processed_time  \
# 0       2024-01-19 09:45:09.215838+00
# 1       2024-01-19 09:45:09.215838+00
# 2       2024-01-21 13:08:11.506112+00
# 3       2024-01-21 06:21:13.609932+00
# 4       2024-01-19 17:11:18.397004+00
# ...

# %% [markdown]
# ## 5. Rename Columns

# %%
job_data = job_data.rename(columns = {'job_link':'job_post_link',
                                      'last_processed_time':'last_modified_date',
                                      'company':'company_name','search_country': 
                                      'job_country','City':'job_city','State':'job_state'})
job_data
# Out:
#                                             job_post_link  \
# 0       https://www.linkedin.com/jobs/view/assistant-n...
# 1       https://www.linkedin.com/jobs/view/executive-c...
# 2       https://www.linkedin.com/jobs/view/sales-lead-...
# 3       https://www.linkedin.com/jobs/view/elevator-pl...
# 4       https://www.linkedin.com/jobs/view/senior-cont...
# ...                                                   ...
# 527496  https://www.linkedin.com/jobs/view/senior-acco...
# 527497  https://www.linkedin.com/jobs/view/registered-...
# 527498  https://www.linkedin.com/jobs/view/juice-baris...
# 527499  https://www.linkedin.com/jobs/view/banquet-and...
# 527500  https://www.linkedin.com/jobs/view/regional-sa...
#
#                    last_modified_date  \
# 0       2024-01-19 09:45:09.215838+00
# 1       2024-01-19 09:45:09.215838+00
# 2       2024-01-21 13:08:11.506112+00
# 3       2024-01-21 06:21:13.609932+00
# 4       2024-01-19 17:11:18.397004+00
# ...

# %% [markdown]
# ##  6. Reorder columns

# %%
job_data = job_data[['job_title', 'company_name', 'job_city','job_state','job_skills','job_level','job_type','job_post_link','last_modified_date','first_seen','job_country']]
job_data
# Out:
#                                                 job_title  \
# 0       Assistant Nurse Manager (RN) Psychiatry Frankl...
# 1                                          Executive Chef
# 2                                          Sales Lead COM
# 3                                        Elevator Planner
# 4                        Senior Content Marketing Manager
# ...                                                   ...
# 527496                                  Senior Accountant
# 527497                                   Registered Nurse
# 527498                            Juice Barista Part Time
# 527499  Banquet and Outlets Manager-Kimpton Hotel Font...
# 527500                             Regional Sales Manager
#
#                                   company_name                    job_city  \
# 0                               MedStar Health                   Baltimore
# 1                      Maggiano's Little Italy             King of Prussia
# ...

# %% [markdown]
# ## A) EDA for finding missing values

# %%
import missingno as msno

msno.matrix(job_data);

# %% [markdown]
# ## 7. Drop Records having NaN or missing values

# %%
job_data = job_data.dropna(subset=['company_name'])
job_data = job_data.dropna(subset=['job_city'])
job_data = job_data.dropna(subset=['job_state'])
job_data = job_data.dropna(subset=['job_skills'])
job_data
# Out:
#                                                 job_title  \
# 0       Assistant Nurse Manager (RN) Psychiatry Frankl...
# 1                                          Executive Chef
# 2                                          Sales Lead COM
# 4                        Senior Content Marketing Manager
# 5                                   Residential Counselor
# ...                                                   ...
# 527495                                 Production Planner
# 527497                                   Registered Nurse
# 527498                            Juice Barista Part Time
# 527499  Banquet and Outlets Manager-Kimpton Hotel Font...
# 527500                             Regional Sales Manager
#
#                                    company_name         job_city job_state  \
# 0                                MedStar Health        Baltimore        MD
# 1                       Maggiano's Little Italy  King of Prussia        PA
# ...

# %% [markdown]
# ## Check for null

# %%
job_data.isnull().any()
# Out:
# job_title             False
# company_name          False
# job_city              False
# job_state             False
# job_skills            False
# job_level             False
# job_type              False
# job_post_link         False
# last_modified_date    False
# first_seen            False
# job_country           False
# dtype: bool

# %% [markdown]
# ## Dataset Description

# %%
job_data.describe()
# Out:
#                               job_title     company_name  job_city job_state  \
# count                            511259           511259    511259    511259
# unique                           253852            49441     11214       242
# top     Customer Service Representative  Health eCareers  New York        CA
# freq                               2546            13101      7277     54602
#
#                                job_skills   job_level job_type  \
# count                              511259      511259   511259
# unique                             509109           2        3
# top     VolunteerMatch, LinkedIn for Good  Mid senior   Onsite
# freq                                   69      392618   506008
#
#                                             job_post_link  \
# count                                              511259
# unique                                             511243
# top     https://www.linkedin.com/jobs/view/assistant-d...
# ...

# %%
job_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 511259 entries, 0 to 527500
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   job_title           511259 non-null  object
#  1   company_name        511259 non-null  object
#  2   job_city            511259 non-null  object
#  3   job_state           511259 non-null  object
#  4   job_skills          511259 non-null  object
#  5   job_level           511259 non-null  object
#  6   job_type            511259 non-null  object
#  7   job_post_link       511259 non-null  object
#  8   last_modified_date  511259 non-null  object
#  9   first_seen          511259 non-null  object
#  10  job_country         511259 non-null  object
# dtypes: object(11)
# memory usage: 46.8+ MB

# %% [markdown]
# ## Dataset Datatypes

# %%
job_data.dtypes
# Out:
# job_title             object
# company_name          object
# job_city              object
# job_state             object
# job_skills            object
# job_level             object
# job_type              object
# job_post_link         object
# last_modified_date    object
# first_seen            object
# job_country           object
# dtype: object

# %% [markdown]
# ## 8. Convert Datatypes

# %%
job_data = job_data.convert_dtypes()
job_data['last_modified_date'] = pd.to_datetime(job_data['last_modified_date'], format='mixed')
job_data.dtypes
# Out:
# job_title                  string[python]
# company_name               string[python]
# job_city                   string[python]
# job_state                  string[python]
# job_skills                 string[python]
# job_level                  string[python]
# job_type                   string[python]
# job_post_link              string[python]
# last_modified_date    datetime64[ns, UTC]
# first_seen                 string[python]
# job_country                string[python]
# dtype: object

# %% [markdown]
# ## Check for duplicates

# %%
df=pd.DataFrame(job_data)
duplicate_mask = df.duplicated(keep=False)
duplicate_rows = df[duplicate_mask]
duplicate_rows.count()
# Out:
# job_title             32
# company_name          32
# job_city              32
# job_state             32
# job_skills            32
# job_level             32
# job_type              32
# job_post_link         32
# last_modified_date    32
# first_seen            32
# job_country           32
# dtype: int64

# %% [markdown]
# ## 9. Remove Duplicate values

# %%
job_data=df.drop_duplicates()
job_data[job_data.duplicated(keep=False)].count()
# Out:
# job_title             0
# company_name          0
# job_city              0
# job_state             0
# job_skills            0
# job_level             0
# job_type              0
# job_post_link         0
# last_modified_date    0
# first_seen            0
# job_country           0
# dtype: int64

# %% [markdown]
# ## Check for insignificant data - data apart from US

# %%
job_country = job_data.job_country.value_counts()
job_country
# Out:
# job_country
# United States     511098
# United Kingdom        92
# Canada                47
# Australia              6
# Name: count, dtype: Int64

# %% [markdown]
# ## 10. Drop rows which are not US

# %%
job_data = job_data.drop(job_data[job_data['job_country'] == 'United Kingdom'].index, axis="index")
job_data = job_data.drop(job_data[job_data['job_country'] == 'Canada'].index, axis="index")
job_data = job_data.drop(job_data[job_data['job_country'] == 'Australia'].index, axis="index")
job_data
# Out:
#                                                 job_title  \
# 0       Assistant Nurse Manager (RN) Psychiatry Frankl...
# 1                                          Executive Chef
# 2                                          Sales Lead COM
# 4                        Senior Content Marketing Manager
# 5                                   Residential Counselor
# ...                                                   ...
# 527495                                 Production Planner
# 527497                                   Registered Nurse
# 527498                            Juice Barista Part Time
# 527499  Banquet and Outlets Manager-Kimpton Hotel Font...
# 527500                             Regional Sales Manager
#
#                                    company_name         job_city job_state  \
# 0                                MedStar Health        Baltimore        MD
# 1                       Maggiano's Little Italy  King of Prussia        PA
# ...

# %% [markdown]
# ## 11. Formatting last_modified_date column

# %%
job_data['last_modified_date'] = job_data['last_modified_date'].dt.strftime('%y/%m/%d')
job_data
# Out:
#                                                 job_title  \
# 0       Assistant Nurse Manager (RN) Psychiatry Frankl...
# 1                                          Executive Chef
# 2                                          Sales Lead COM
# 4                        Senior Content Marketing Manager
# 5                                   Residential Counselor
# ...                                                   ...
# 527495                                 Production Planner
# 527497                                   Registered Nurse
# 527498                            Juice Barista Part Time
# 527499  Banquet and Outlets Manager-Kimpton Hotel Font...
# 527500                             Regional Sales Manager
#
#                                    company_name         job_city job_state  \
# 0                                MedStar Health        Baltimore        MD
# 1                       Maggiano's Little Italy  King of Prussia        PA
# ...

# %% [markdown]
# ## B) Bar Graph of Top 10 Job Titles

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))
colors = sns.color_palette('viridis', len(job_data['job_title'].unique()))
top_job_titles = job_data['job_title'].value_counts().head(10)
top_job_titles.plot(kind='bar', color=colors, edgecolor='black')

plt.title('Top 10 Job Titles', fontsize=16)
plt.xlabel('Job Titles', fontsize=14)
plt.ylabel('Number of Job Listings', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()

# %% [markdown]
# ## C) Horizontal Bar Graph for Top 10 skills

# %%
skills = job_data['job_skills'].str.split(',').explode()
skills_count = skills.str.strip().value_counts()

top_skills = skills_count.head(10)
plt.figure(figsize=(10, 6))
top_skills.sort_values().plot(kind='barh')
plt.title('Top 10 Skills')
plt.xlabel('Skills')
plt.ylabel('Frequency of Skills')
plt.show()

# %% [markdown]
# ## D) Pie Chart representing the Data Distribution of the States

# %%
job_level_distribution = job_data['job_state'].value_counts().head(10)
job_level_distribution.plot(kind='pie', autopct='%1.1f%%', figsize=(8, 8))
plt.title('Data Distribution of States')
plt.show()

# %% [markdown]
# ## Building Correlation Matrix

# %%
jobs_categorical = job_data[['job_post_link','job_title', 'company_name', 'job_city','job_state','job_level','job_type','last_modified_date','job_skills']]
jobs_categorical = jobs_categorical.head(500)
jobs_categorical
# Out:
#                                          job_post_link  \
# 0    https://www.linkedin.com/jobs/view/assistant-n...
# 1    https://www.linkedin.com/jobs/view/executive-c...
# 2    https://www.linkedin.com/jobs/view/sales-lead-...
# 4    https://www.linkedin.com/jobs/view/senior-cont...
# 5    https://www.linkedin.com/jobs/view/residential...
# ..                                                 ...
# 518  https://www.linkedin.com/jobs/view/store-manag...
# 519  https://www.linkedin.com/jobs/view/retail-sale...
# 520  https://www.linkedin.com/jobs/view/assistant-g...
# 521  https://www.linkedin.com/jobs/view/environment...
# 522  https://www.linkedin.com/jobs/view/locums-obst...
#
#                                              job_title  \
# 0    Assistant Nurse Manager (RN) Psychiatry Frankl...
# 1                                       Executive Chef
# 2                                       Sales Lead COM
# 4                     Senior Content Marketing Manager
# ...

# %%
import scipy.stats as ss
import seaborn as sns
from scipy.stats import chi2_contingency
import numpy as np

def cramers_V(var1,var2) :
  crosstab =np.array(pd.crosstab(var1,var2, rownames=None, colnames=None)) # Cross table building
  stat = chi2_contingency(crosstab)[0] # Keeping of the test statistic of the Chi2 test
  obs = np.sum(crosstab) # Number of observations
  mini = min(crosstab.shape)-1 # Take the minimum value between the columns and the rows of the cross table
  return (stat/(obs*mini))

# %%
rows= []

for var1 in jobs_categorical:
  col = []
  for var2 in jobs_categorical :
    cramers =cramers_V(jobs_categorical[var1], jobs_categorical[var2]) # Cramer's V test
    col.append(round(cramers,2)) # Keeping of the rounded value of the Cramer's V  
  rows.append(col)
  
cramers_results = np.array(rows)
df = pd.DataFrame(cramers_results, columns = jobs_categorical.columns, index =jobs_categorical.columns)
df
# Out:
#                     job_post_link  job_title  company_name  job_city  \
# job_post_link                 1.0       1.00          1.00      1.00
# job_title                     1.0       1.00          0.97      0.93
# company_name                  1.0       0.97          1.00      0.80
# job_city                      1.0       0.93          0.80      1.00
# job_state                     1.0       0.92          0.80      0.94
# job_level                     1.0       0.99          0.96      0.78
# job_type                      1.0       1.00          1.00      1.00
# last_modified_date            1.0       0.96          0.75      0.80
# job_skills                    1.0       1.00          1.00      1.00
#
#                     job_state  job_level  job_type  last_modified_date  \
# job_post_link            1.00       1.00      1.00                1.00
# job_title                0.92       0.99      1.00                0.96
# ...

# %% [markdown]
# ## E) Creating HeatMap for the Correlation Matrix

# %%
# generating 2-D 10x10 matrix of random numbers
data = np.random.randint(low=1,
                         high=100,
                         size=(10, 10))
annot = True
hm = sns.heatmap(data=df,
                annot=annot)
plt.show()

# %% [markdown]
# ## F) Representing the Top 5 job titles with the Top 5 Cities

# %%
plt.plot(job_data['job_city'].head(5), job_data['job_title'].value_counts().head(5), linestyle='dashed')
plt.title('Top 5 job titles with the Top 5 Cities')
plt.xlabel('Cities')
plt.ylabel('Number of jobs')
plt.show()

# %% [markdown]
# ## G) Scatter Plot for the Skills required for the 10 job titles

# %%
plt.scatter(job_data['job_skills'].value_counts().head(10), job_data['job_title'].head(10))
plt.title('Skills required for the 10 job titles')
plt.xlabel('Number of skills')
plt.ylabel('Job Titles')
plt.show()

# %% [markdown]
# ## H) Box Plot for the Job Titles

# %%
plt.boxplot(job_data['job_title'].value_counts().head(10),patch_artist=True) 
plt.title('Box Plot for job titles')
plt.xlabel('Job Titles')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# ## I) Histogram for 100 Cities

# %%
job_city = job_data.job_city.value_counts()
myHist = plt.hist(job_city.head(100))
plt.title("Distribution of City")
plt.xlabel("No of Records")
plt.ylabel("No of Cities")
plt.show()

# %% [markdown]
# ## J) Line Graph for the number of records with latest modification date

# %%
no_rec_last = job_data.last_modified_date.value_counts()
last_list = no_rec_last.to_dict()

x = []
y = []

for k in last_list:
    x.append(k)
    y.append(last_list.get(k))
    
plt.plot(x, y)
plt.title("Last Processed Date")
plt.xlabel("Date")
plt.ylabel("No of records")
plt.show()

# %% [markdown]
# ## K) Line Graph for the number of records with first seen date

# %%
no_rec_first = job_data.first_seen.value_counts()
first_list = no_rec_first.to_dict()

x = []
y = []

for k in first_list:
    x.append(k)
    y.append(first_list.get(k))
    
plt.plot(x, y)
plt.title("First_seen_date")
plt.xlabel("Date")
plt.ylabel("No of records")
plt.show()
